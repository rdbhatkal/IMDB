# %% [markdown]
# ## Load Data

# %%
#Importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
# Load title basics file 
df = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0094859     movie                                         Chief Zabu
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                                 Chief Zabu        0       2016      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74                  Comedy

# %%
# Load title rating file 
rating = pd.read_csv("Data/title_rating.csv.gz", low_memory = False)
rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.8       256
# 2  tt0000005            6.2      2519
# 3  tt0000006            5.1       173
# 4  tt0000007            5.4       783

# %%
# Load in your csv.gz's of results for combined years
df1 = pd.read_csv("Data/tmdb_results_combined.csv.gz", low_memory = False)
df1.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# 0                                   NaN       NaN               NaN
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4  http://www.wkw-inthemoodforlove.com/     843.0                cn
#
#     original_title  ...     revenue  runtime  \
# 0              NaN  ...         NaN      NaN
# 1  The Fantasticks  ...         0.0     86.0
# 2    For the Cause  ...         0.0    100.0
# 3             Gang  ...         0.0    152.0
# 4             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0           5.5       22.0           NaN
# 2    0.0           5.1        8.0           NaN
# 3    0.0           0.0        0.0           NaN
# 4    0.0           8.1     1950.0            PG
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Transformation steps:

# %% [markdown]
# ### Normalize Genre:

# %%
## create a col with a list of genres
df['genres_split'] = df['genres'].str.split(',')
df
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0094859     movie                                         Chief Zabu
# ...          ...       ...                                                ...
# 82245  tt9914942     movie                             Life Without Sara Amat
# 82246  tt9915872     movie                               The Last White Witch
# 82247  tt9916170     movie                                      The Rehearsal
# 82248  tt9916190     movie                                          Safeguard
# 82249  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                                     Chief Zabu        0       2016      NaN
# ...                                          ...      ...        ...      ...
# 82245                 La vida sense la Sara Amat        0       2019      NaN
# 82246                  My Girlfriend is a Wizard        0       2019      NaN
# 82247                                   O Ensaio        0       2019      NaN
# 82248                                  Safeguard        0       2020      NaN
# 82249                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                  74                     Comedy
# ...               ...                        ...
# 82245              74                      Drama
# 82246              97       Comedy,Drama,Fantasy
# 82247              51                      Drama
# 82248              95  Action,Adventure,Thriller
# 82249              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                           [Comedy]
# ...                              ...
# 82245                        [Drama]
# 82246       [Comedy, Drama, Fantasy]
# 82247                        [Drama]
# 82248  [Action, Adventure, Thriller]
# 82249               [Drama, History]
#
# [82250 rows x 10 columns]

# %%
## exploding the column of lists
exploded = df.explode('genres_split')
exploded
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 82248  tt9916190     movie                                          Safeguard
# 82248  tt9916190     movie                                          Safeguard
# 82248  tt9916190     movie                                          Safeguard
# 82249  tt9916362     movie                                              Coven
# 82249  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 82248                                  Safeguard        0       2020      NaN
# 82248                                  Safeguard        0       2020      NaN
# 82248                                  Safeguard        0       2020      NaN
# 82249                                   Akelarre        0       2020      NaN
# 82249                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 82248              95  Action,Adventure,Thriller       Action
# 82248              95  Action,Adventure,Thriller    Adventure
# 82248              95  Action,Adventure,Thriller     Thriller
# 82249              92              Drama,History        Drama
# 82249              92              Drama,History      History
#
# [153682 rows x 10 columns]

# %%
## saving the unique values from the exploded column
unique_genres = sorted(exploded['genres_split'].dropna().unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
# Create a new table from the exploded df
title_genres = exploded[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)

title_genres = title_genres.drop(columns='genres_split')
title_genres
# Out:
#           tconst  genre_id
# 0      tt0035423         5
# 0      tt0035423         9
# 0      tt0035423        18
# 1      tt0062336         7
# 2      tt0069049         7
# ...          ...       ...
# 82248  tt9916190         0
# 82248  tt9916190         2
# 82248  tt9916190        23
# 82249  tt9916362         7
# 82249  tt9916362        11
#
# [153682 rows x 2 columns]

# %%
# Check datatypes
title_genres.dtypes
# Out:
# tconst      object
# genre_id     int64
# dtype: object

# %%
# Convert the mapper dictionary into a final genres table
genre = pd.DataFrame({'Genre_Name' : genre_map.keys(),
                     'Genre_Id': genre_map.values()})
genre.head()
# Out:
#   Genre_Name  Genre_Id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
# Check datatypes
genre.dtypes
# Out:
# Genre_Name    object
# Genre_Id       int64
# dtype: object

# %% [markdown]
# ### Discard unnecessary information from title_basics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82250 entries, 0 to 82249
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          82250 non-null  object
#  1   titleType       82250 non-null  object
#  2   primaryTitle    82250 non-null  object
#  3   originalTitle   82250 non-null  object
#  4   isAdult         82250 non-null  int64
#  5   startYear       82250 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  82250 non-null  int64
#  8   genres          82250 non-null  object
#  9   genres_split    82250 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 6.3+ MB

# %%
df = df.drop(['originalTitle','isAdult', 'titleType','genres','genres_split'], axis = 1)
df
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0094859                                         Chief Zabu
# ...          ...                                                ...
# 82245  tt9914942                             Life Without Sara Amat
# 82246  tt9915872                               The Last White Witch
# 82247  tt9916170                                      The Rehearsal
# 82248  tt9916190                                          Safeguard
# 82249  tt9916362                                              Coven
#
#        startYear  endYear  runtimeMinutes
# 0           2001      NaN             118
# 1           2020      NaN              70
# 2           2018      NaN             122
# 3           2005      NaN             100
# 4           2016      NaN              74
# ...          ...      ...             ...
# 82245       2019      NaN              74
# 82246       2019      NaN              97
# 82247       2019      NaN              51
# 82248       2020      NaN              95
# 82249       2020      NaN              92
#
# [82250 rows x 5 columns]

# %%
# copying to another dataframe
title_basics = df.copy()

# %% [markdown]
# ### Discard unnecessary information from tmdb data

# %%
#tmdb overview
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53734 entries, 0 to 53733
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                53734 non-null  object
#  1   adult                  53712 non-null  float64
#  2   backdrop_path          33783 non-null  object
#  3   belongs_to_collection  3452 non-null   object
#  4   budget                 53712 non-null  float64
#  5   genres                 53712 non-null  object
#  6   homepage               13073 non-null  object
#  7   id                     53712 non-null  float64
#  8   original_language      53712 non-null  object
#  9   original_title         53712 non-null  object
#  10  overview               52569 non-null  object
#  11  popularity             53712 non-null  float64
#  12  poster_path            49052 non-null  object
#  13  production_companies   53712 non-null  object
#  14  production_countries   53712 non-null  object
#  15  release_date           52847 non-null  object
#  16  revenue                53712 non-null  float64
#  17  runtime                53712 non-null  float64
#  18  spoken_languages       53712 non-null  object
#  19  status                 53712 non-null  object
#  20  tagline                20367 non-null  object
#  21  title                  53712 non-null  object
#  22  video                  53712 non-null  float64
#  23  vote_average           53712 non-null  float64
#  24  vote_count             53712 non-null  float64
#  25  certification          13441 non-null  object
# dtypes: float64(9), object(17)
# memory usage: 10.7+ MB

# %%
# check for duplicates
df1.duplicated().sum()
# Out:
# 21

# %%
df1.drop_duplicates(inplace = True)

# %%
# check for duplicates again
df1.duplicated().sum()
# Out:
# 0

# %%
 # Extract certain columns
tmdb = df1[['imdb_id','budget','revenue', 'certification']]
tmdb
# Out:
#          imdb_id      budget     revenue certification
# 0              0         NaN         NaN           NaN
# 1      tt0113026  10000000.0         0.0           NaN
# 2      tt0113092         0.0         0.0           NaN
# 3      tt0116391         0.0         0.0           NaN
# 4      tt0118694    150000.0  12854953.0            PG
# ...          ...         ...         ...           ...
# 53729  tt9895024         0.0         0.0           NaN
# 53730  tt9896876         0.0         0.0         PG-13
# 53731  tt9898844         0.0         0.0           NaN
# 53732  tt9900940         0.0         0.0           NaN
# 53733  tt9907782         0.0   4588389.0             R
#
# [53713 rows x 4 columns]

# %% [markdown]
# ## MySQL Database Requirements

# %%
import pymysql
import pandas as pd
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
connection_str = "mysql+pymysql://root:root@localhost/movies"

# %%
# Create engine
engine = create_engine(connection_str)

# %%
# create database
create_database(connection_str)

# %%
# Transform to tables
title_basics.to_sql('title_basics', engine, if_exists = 'replace')
rating.to_sql('title_rating', engine, if_exists = 'replace')
title_genres.to_sql('title_genres', engine, if_exists = 'replace')
genre.to_sql('genres', engine, if_exists = 'replace')
tmdb.to_sql('tmdb_data', engine, if_exists = 'replace')
# Out:
# 53713

# %% [markdown]
# ### title_basics tables with primary key

# %%
title_basics.dtypes
# Out:
# tconst             object
# primaryTitle       object
# startYear           int64
# endYear           float64
# runtimeMinutes      int64
# dtype: object

# %%
## title_basics table
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = title_basics['tconst'].fillna('').map(len).max()
title_len = title_basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Integer(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
# Save to sql with dtype and index=False
title_basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 82250

# %%
# update the table and set the primary key
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
# show the first 5 rows of the table using a SQL query
q = """
SELECT *
FROM title_basics
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold       2001
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...       2020
# 2  tt0069049                         The Other Side of the Wind       2018
# 3  tt0088751                                  The Naked Monster       2005
# 4  tt0094859                                         Chief Zabu       2016
#
#   endYear  runtimeMinutes
# 0    None             118
# 1    None              70
# 2    None             122
# 3    None             100
# 4    None              74

# %% [markdown]
# ### rating table with primary key

# %%
rating.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
## rating table
## Calculate max string lengths for object columns
key_len = rating['tconst'].fillna('').map(len).max()

## Create a schema dictonary using Sqlalchemy datatype objects
df_schema2 = {
    "tconst": String(key_len+1),
    'averageRating':Float(),
    'numVotes':Integer()}

# %%
# Save to sql with dtype and index=False
rating.to_sql('title_rating',engine,dtype=df_schema2,if_exists='replace',index=False)
# Out:
# 474688

# %%
# update the table and set the primary key
engine.execute('ALTER TABLE title_rating ADD PRIMARY KEY (`tconst`);')

# %%
# show the first 5 rows of the table using a SQL query
q = """
SELECT *
FROM title_rating
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.8       256
# 2  tt0000005            6.2      2519
# 3  tt0000006            5.1       173
# 4  tt0000007            5.4       783

# %% [markdown]
# ### genre table with primary key

# %%
genre.dtypes
# Out:
# Genre_Name    object
# Genre_Id       int64
# dtype: object

# %%
## Set the dataframe index and use index=True 
genre.set_index('Genre_Id').to_sql('genres',engine,index=True, if_exists = 'replace')
# Out:
# 26

# %%
# show the first 5 rows of the table using a SQL query
q = """
SELECT *
FROM genres
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#    Genre_Id Genre_Name
# 0         0     Action
# 1         1      Adult
# 2         2  Adventure
# 3         3  Animation
# 4         4  Biography

# %% [markdown]
# ### tmdb table with primary key

# %%
tmdb.dtypes
# Out:
# imdb_id           object
# budget           float64
# revenue          float64
# certification     object
# dtype: object

# %%
## tmdb table
## Calculate max string lengths for object columns
key_len = tmdb['imdb_id'].fillna('').map(len).max()
cert_len = tmdb['certification'].fillna('').map(len).max()

## Create a schema dictonary using Sqlalchemy datatype objects
df_schema3 = {
    "imdb_id": String(key_len+1),
    'budget':Float(),
    'revenue':Float(),
    "certification":Text(cert_len+1)}

# %%
# Save to sql with dtype and index=False
tmdb.to_sql('tmdb_data',engine,dtype=df_schema3,if_exists='replace',index=False)
# Out:
# 53713

# %%
# update the table and set the primary key
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
# show the first 5 rows of the table using a SQL query
q = """
SELECT *
FROM tmdb_data
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget     revenue certification
# 0          0         NaN         NaN          None
# 1  tt0035423  48000000.0  76019000.0         PG-13
# 2  tt0062336         0.0         0.0          None
# 3  tt0069049  12000000.0         0.0             R
# 4  tt0088751    350000.0         0.0          None

# %% [markdown]
# ### First 5 rows of title_genres table (joiner table)

# %%
# show the first 5 rows of the joiner table using a SQL query
q = """
SELECT *
FROM title_genres
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#    index     tconst  genre_id
# 0      0  tt0035423         5
# 1      0  tt0035423         9
# 2      0  tt0035423        18
# 3      1  tt0062336         7
# 4      2  tt0069049         7

# %% [markdown]
# ### Show all tables

# %%
# Show all tables 
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3     title_rating
# 4        tmdb_data
