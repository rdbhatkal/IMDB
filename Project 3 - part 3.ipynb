# %%
#Importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
# Load in your csv.gz's of results for combined years
df = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0094859     movie                                         Chief Zabu
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                                 Chief Zabu        0       2016      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74                  Comedy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82250 entries, 0 to 82249
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          82250 non-null  object
#  1   titleType       82250 non-null  object
#  2   primaryTitle    82250 non-null  object
#  3   originalTitle   82250 non-null  object
#  4   isAdult         82250 non-null  int64
#  5   startYear       82250 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  82250 non-null  int64
#  8   genres          82250 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 5.6+ MB

# %%
## create a col with a list of genres
df['genres_split'] = df['genres'].str.split(',')
df
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0094859     movie                                         Chief Zabu
# ...          ...       ...                                                ...
# 82245  tt9914942     movie                             Life Without Sara Amat
# 82246  tt9915872     movie                               The Last White Witch
# 82247  tt9916170     movie                                      The Rehearsal
# 82248  tt9916190     movie                                          Safeguard
# 82249  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                                     Chief Zabu        0       2016      NaN
# ...                                          ...      ...        ...      ...
# 82245                 La vida sense la Sara Amat        0       2019      NaN
# 82246                  My Girlfriend is a Wizard        0       2019      NaN
# 82247                                   O Ensaio        0       2019      NaN
# 82248                                  Safeguard        0       2020      NaN
# 82249                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                  74                     Comedy
# ...               ...                        ...
# 82245              74                      Drama
# 82246              97       Comedy,Drama,Fantasy
# 82247              51                      Drama
# 82248              95  Action,Adventure,Thriller
# 82249              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                           [Comedy]
# ...                              ...
# 82245                        [Drama]
# 82246       [Comedy, Drama, Fantasy]
# 82247                        [Drama]
# 82248  [Action, Adventure, Thriller]
# 82249               [Drama, History]
#
# [82250 rows x 10 columns]

# %%
## exploding the column of lists
exploded = df.explode('genres_split')
exploded.head(10)
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 3  tt0088751     movie                                  The Naked Monster
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0094859     movie                                         Chief Zabu
# 5  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 3                          The Naked Monster        0       2005      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                                 Chief Zabu        0       2016      NaN
# 5                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres genres_split
# 0             118  Comedy,Fantasy,Romance       Comedy
# 0             118  Comedy,Fantasy,Romance      Fantasy
# 0             118  Comedy,Fantasy,Romance      Romance
# 1              70                   Drama        Drama
# 2             122                   Drama        Drama
# 3             100    Comedy,Horror,Sci-Fi       Comedy
# 3             100    Comedy,Horror,Sci-Fi       Horror
# 3             100    Comedy,Horror,Sci-Fi       Sci-Fi
# 4              74                  Comedy       Comedy
# 5             126                   Drama        Drama

# %%
## saving the unique values from the exploded column
unique_genres = sorted(exploded['genres_split'].dropna().unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
title_genres = exploded[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
df['genre_id'] = df['genres_split'].map(genre_map)
df = df.drop(columns='genres_split')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 ## make new integer genre_id and drop string genres
# ----> 2 df['genre_id'] = df['genres_split'].map(genre_map)
#       3 df = df.drop(columns='genres_split')
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# -> 4237     new_values = self._map_values(arg, na_action=na_action)
#    4238     return self._constructor(new_values, index=self.index).__finalize__(
#    4239         self, method="map"
#    4240     )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\base.py:852, in IndexOpsMixin._map_values(self, mapper, na_action)
#     848     return cat.map(mapper)
#     850 values = self._values
# --> 852 indexer = mapper.index.get_indexer(values)
#     853 new_values = algorithms.take_nd(mapper._values, indexer)
#     855 return new_values
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3784, in Index.get_indexer(self, target, method, limit, tolerance)
#    3779     target = target.astype(dtype, copy=False)
#    3780     return this._get_indexer(
#    3781         target, method=method, limit=limit, tolerance=tolerance
#    3782     )
# -> 3784 return self._get_indexer(target, method, limit, tolerance)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3809, in Index._get_indexer(self, target, method, limit, tolerance)
#    3804         # error: "IndexEngine" has no attribute "_extract_level_codes"
#    3805         tgt_values = engine._extract_level_codes(  # type: ignore[attr-defined]
#    3806             target
#    3807         )
# -> 3809     indexer = self._engine.get_indexer(tgt_values)
#    3811 return ensure_platform_int(indexer)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:305, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas\_libs\hashtable_class_helper.pxi:5247, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'
